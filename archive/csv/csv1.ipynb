# %%
import numpy as np
# from scipy import signal
# from scipy import linalg
# from scipy.io import wavfile
# import scipy.io
import matplotlib as mpl
import matplotlib.pyplot as plt
import time
import csv

# %%
with open('2018-12-21T22-00-00_LNA_30_PGA_12_TIA_0_S_HIGH.csv') as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    for row in csv_reader:
#         print(len(row)-6)
#         print(row[0], row[1])
        data_row = row[6:]
#         print(data_row[:5])
        data_row = list(map(float, data_row))
        print(data_row[:5])
        #         if line_count == 0:
#             print(f'Column names are {", ".join(row)}')
#             line_count += 1
#         else:
#             print(f'\t{row[0]} works in the {row[1]} department, and was born in {row[2]}.')
#             line_count += 1
#     print(f'Processed {line_count} lines.')
# Out:
# [-132.964, -132.988, -133.013, -133.084, -133.021]
# [-136.73, -136.918, -136.83, -136.741, -136.856]
# [-136.815, -136.751, -136.636, -136.77, -136.795]
# [-136.746, -136.732, -136.786, -136.893, -136.855]
# [-136.903, -136.859, -136.809, -136.985, -136.702]
# [-136.865, -136.899, -136.848, -136.887, -136.814]
# [-136.79, -136.755, -136.868, -136.882, -136.837]
# [-136.797, -136.866, -136.983, -136.832, -136.897]
# [-136.835, -136.816, -136.809, -136.773, -136.843]
# [-136.831, -136.851, -136.867, -136.874, -136.91]
# [-136.736, -136.718, -136.749, -136.815, -136.75]
# [-136.708, -136.705, -136.872, -136.87, -136.85]
# [-136.877, -136.934, -136.844, -136.818, -136.847]
# [-136.747, -136.827, -136.876, -136.82, -136.791]
# [-136.826, -136.846, -136.874, -136.872, -136.852]
# [-136.844, -136.918, -136.818, -136.844, -136.704]
# [-136.7, -136.708, -136.684, -136.746, -136.756]
# [-136.746, -136.761, -136.767, -136.621, -136.649]
# [-136.884, -136.902, -136.792, -136.703, -136.637]
# ...

# %%
from numpy import genfromtxt
data = genfromtxt('2018-12-21T20-00-00_LNA_30_PGA_12_TIA_0_S_HIGH.csv', delimiter=',')

print(f'Start freq: {data[0, 2]/float(1e9)}')
print(f'End freq: {data[0, 3]/float(1e9)}')

spec_data = data[:, 6:]
print(len(spec_data))
print(spec_data)

# spec_data_db = map(np.log10, spec_data)


plt.imshow(spec_data)
plt.show()
# Out:
# Start freq: 2.02700000002
# End freq: 2.03699999998
# 732
# [[-132.766 -132.733 -132.689 ... -132.784 -132.857 -132.747]
#  [-136.792 -136.813 -136.909 ... -136.797 -136.873 -136.839]
#  [-136.974 -136.998 -136.953 ... -136.73  -136.88  -136.917]
#  ...
#  [-136.945 -136.934 -136.908 ... -136.824 -136.8   -136.85 ]
#  [-136.707 -136.901 -136.891 ... -136.894 -136.75  -136.718]
#  [-136.747 -136.772 -136.932 ... -136.735 -136.742 -136.776]]
