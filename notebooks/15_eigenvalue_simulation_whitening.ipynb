# %%
import numpy as np
import math
import matplotlib as mpl
import matplotlib.pyplot as plt
plt.style.use('seaborn-deep')
from mpl_toolkits import mplot3d as mpl3d
from scipy import signal, stats, linalg, fft

# import our 'specsens' package with the help of 'sys'
import sys
sys.path.insert(0, '..')
import specsens as ss

# %%
# eigenvalue detector simulation using mme

_ = ss.eigenvalue_whitening_sim(
    gens=100,  # generations, number of environments
    itrs=20,  # iterations, number of tests in each environment
    f_sample=1e6,  # in Hz
    signal_power=1.0,  # in dB
    f_center=-3e5,  # signal center frequency
    noise_power=15.0,  # in dB
    length_sec=0.01,  # length of each sample in seconds
    theo_pfa=0.1,  # probability of false alarm
    noise_uncert=1.0,  # standard deviation of the noise normal distribution
    num_procs=None,  # number of processes to run in parallel
    seed=None,  # set seed for reproducibility
    cov_size=10,  # covariance matrix size
    sampling_factor=1.75,
    f_min=-4e5,
    f_max=-2e5,
    pre_gens=8,
    pre_itrs=265)

# there is no probability of detection statistic yet...
# Out:
# ---- Simulation parameters ----
# Generations:    100
# Iterations:     20
# Total iters:    2000
# Signal power:   1.00 dB
# Sig cent. freq: -300000.0 Hz
# Noise power:    15.00 dB
# Noise uncert:   1.00 dB
# SNR:            -14.00 dB
# Signal length:  0.010000 s
# Signal samples: 10000
# Num. of bands:  1
# Band to detect: 0
# ---- Simulation stats theory ----
# Prob false alarm: 0.1000
# Prob detection:   nan
# Threshold:        1.1855
# ---- Training prewhitening matrix ----
# Using 8 processes on 8 cores
# 100%|██████████| 8/8 [03:20<00:00, 25.05s/it]
# biases mean 0.09986957946908216
# biases std  0.0015847233339890453
# ---- Running simulation ----
# Using 8 processes on 8 cores
# 100%|██████████| 100/100 [00:42<00:00,  2.33it/s]
# ---- Simulation stats ----
# Prob false alarm theory: 0.1000
# Prob false alarm sim:    0.0917
# Prob detection theory:   nan
# Prob detection sim:      1.0000
# ---- Distribution stats ----
# Sig present mean: 1.8657
# Sig absent  mean: 1.1022
# Sig present var:  0.0504
# Sig absent  var:  0.0037
# Sig present std:  0.2245
# Sig absent  std:  0.0609
