# %%
import numpy as np
import math
import matplotlib as mpl
import matplotlib.pyplot as plt
plt.style.use('seaborn-deep')
from mpl_toolkits import mplot3d as mpl3d
from scipy import signal, stats, linalg, fft

# import our 'specsens' package with the help of 'sys'
import sys
sys.path.insert(0, '..')
import specsens as ss

# %%
# narrow band energy detector simulation

_ = ss.narrowband_sim(
    gens=100,  # generations, number of environments
    itrs=200,  # iterations, number of tests in each environment
    f_sample=1e6,  # in Hz
    signal_power=0.0,  # in dB
    noise_power=7.0,  # in dB
    length_sec=0.01,  # length of each section in seconds
    theo_pfa=0.01,  # probability of false alarm
    noise_uncert=0.0,  # standard deviation of the noise normal distribution in dB
    seed=None,  # set seed for reproducibility
    num_procs=None)  # number of processes to run in parallel
# Out:
# ---- Simulation parameters ----
# Generations:    100
# Iterations:     200
# Total iters:    20000
# Signal power:   0.00 dB
# Sig cent. freq: -100000.0 Hz
# Noise power:    7.00 dB
# Noise uncert:   0.00 dB
# SNR:            -7.00 dB
# Signal length:  0.010000 s
# Signal samples: 10000
# ---- Simulation stats theory ----
# Prob false alarm: 0.0100
# Prob detection:   1.0000
# Threshold:        51292.0246
# ---- Running simulation ----
# Using 8 processes on 8 cores
# 100%|██████████| 100/100 [00:08<00:00, 11.26it/s]
# ---- Simulation stats ----
# Prob false alarm theory: 0.0100
# Prob false alarm sim:    0.0097
# Prob detection theory:   1.0000
# Prob detection sim:      1.0000
# ---- Distribution stats ----
# Sig present mean: 60114.2755
# Sig absent  mean: 50122.2826
# Sig present var:  354760.4150
# Sig absent  var:  244384.5119
# Sig present std:  595.6177
# Sig absent  std:  494.3526
