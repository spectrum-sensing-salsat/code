# %%
import numpy as np
import math
import matplotlib as mpl
import matplotlib.pyplot as plt
plt.style.use('seaborn-deep')
from mpl_toolkits import mplot3d as mpl3d
from scipy import signal, stats, linalg, fft

# import our 'specsens' package with the help of 'sys'
import sys
sys.path.insert(0, '..')
import specsens as ss

# %%
# narrow band energy detector simulation

_ = ss.narrowband_sim(
    gens=100,  # generations, number of environments
    itrs=300,  # iterations, number of tests in each environment
    f_sample=1e6,  # in Hz
    signal_power=0.0,  # in dB
    noise_power=7.0,  # in dB
    length_sec=0.001024,  # length of each section in seconds
    theo_pfa=0.01,  # probability of false alarm
    noise_uncert=0.0,  # standard deviation of the noise normal distribution in dB
    seed=None,  # set seed for reproducibility
    num_procs=None)  # number of processes to run in parallel
# Out:
# ---- Simulation parameters ----
# Generations:    100
# Iterations:     300
# Total iters:    30000
# Signal power:   0.00 dB
# Sig cent. freq: -100000.0 Hz
# Noise power:    7.00 dB
# Noise uncert:   0.00 dB
# SNR:            -7.00 dB
# Signal length:  0.001024 s
# Signal samples: 1024
# ---- Simulation stats theory ----
# Prob false alarm: 0.0100
# Prob detection:   0.9997
# Threshold:        5512.6106
# ---- Running simulation ----
# Using 8 processes on 8 cores
# 100%|██████████| 100/100 [00:03<00:00, 26.58it/s]
# ---- Simulation stats ----
# Prob false alarm theory: 0.0100
# Prob false alarm sim:    0.0116
# Prob detection theory:   0.9997
# Prob detection sim:      0.9998
# ---- Distribution stats ----
# Sig present mean: 6157.9857
# Sig absent  mean: 5132.9800
# Sig present var:  36350.3467
# Sig absent  var:  26417.7005
# Sig present std:  190.6577
# Sig absent  std:  162.5352
