# %%
import numpy as np
import math
import matplotlib as mpl
import matplotlib.pyplot as plt
plt.style.use('seaborn-deep')  # change pyplots default style
from mpl_toolkits import mplot3d as mpl3d
from scipy import signal, stats, linalg, fft

# import our 'specsens' package with the help of 'sys'
import sys
sys.path.insert(0, '..')
import specsens as ss

# %%
# mpl.use("pgf")  # to display graphs remove this line
mpl.rcParams.update({
    'pgf.texsystem': 'pdflatex',
    'font.family': 'serif',
    'text.usetex': True,
    'pgf.rcfonts': False,
})
line = 0.75

# %%
N = 101
n = np.linspace(-5, 5, N)

gauss = np.exp(-n**2)
gauss1 = -2*n*np.exp(-n**2)
gauss2 = (4*n**2-2)*np.exp(-n**2)
mexican = 2/(3**.5*np.pi**(1/4))*np.exp(-n**2*.5)*(1-n**2)

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(7, 3))
ax1.plot(n, gauss, '-', linewidth=line * 1.2, color='C0', label=r'$\psi(n)$', aa=True)
ax1.plot(n, gauss1, '-', linewidth=line * 1.2, color='C1', label=r'$\psi^{\prime}(n)$', aa=True)
ax1.plot(n, gauss2, '-', linewidth=line * 1.2, color='C3', label=r'$\psi^{\prime\prime}(n)$', aa=True)
ax2.plot(n, mexican, '-', linewidth=line * 1.2, color='C0', label=r'$\psi(n)$', aa=True)
ax1.set_xlabel(r'$n$')
# ax1.set_ylabel(r'$\psi(n)$')
ax1.set_title(r'Gaussian wavelet group')
ax2.set_xlabel(r'$n$')
ax2.set_ylabel(r'$\psi(n)$')
ax2.set_title(r'Mexican hat wavelet')
ax1.grid(linewidth=0.3)
ax2.grid(linewidth=0.3)
plt.tight_layout()
ax1.legend()
# ax2.legend()
plt.savefig('out/appe/wavelets.pgf')
