# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
from scipy import signal

import sys
sys.path.insert(0, '..')
import specsens as ss

# %%
# Narrow band energy detector simulation

_ = ss.sim_narrow(
    gens=300,
    itrs=300,
    f_sample=1e6,  # in Hz
    signal_strength=0.0,  # in dB
    noise_strength=13.0,  # in dB
    length_sec=0.001024,  # in seconds
    theo_pfa=0.1,  # probability of false alarm
    noise_un=1.0)  # standard deviation of the noise normal distribution
# Out:
# ---- Simulation parameter ----
# Generations:    300
# Iterations:     300
# Total Iters:    90000
# Signal power:   0.00 dB
# Noise power:    13.00 dB
# Noise uncert.:  1.00 dB
# SNR:            -13.00 dB
# Signal length:  0.001024 sec
# Signal samples: 1024
# ---- Simulation stats theory ----
# Prob false alarm 0.1000
# Prob detection   0.6145
# Threshold        21253.8895
# ---- Running simulation ----
#    infs left at  0.00%
#  59.59s left at  0.33%
#  56.86s left at  0.67%
#  58.83s left at  1.00%
#  59.00s left at  1.33%
#  60.76s left at  1.67%
#  56.22s left at  2.00%
#  56.87s left at  2.33%
#  59.40s left at  2.67%
#  54.68s left at  3.00%
#  55.87s left at  3.33%
#  54.14s left at  3.67%
#  56.94s left at  4.00%
#  64.12s left at  4.33%
#  62.44s left at  4.67%
#  59.51s left at  5.00%
#  57.63s left at  5.33%
#  53.81s left at  5.67%
#  60.93s left at  6.00%
#  55.75s left at  6.33%
#  53.57s left at  6.67%
#  56.49s left at  7.00%
#  53.51s left at  7.33%
#  58.63s left at  7.67%
#  53.73s left at  8.00%
#  61.33s left at  8.33%
#  56.41s left at  8.67%
#  57.31s left at  9.00%
#  51.94s left at  9.33%
#  53.78s left at  9.67%
#  52.90s left at 10.00%
#  52.96s left at 10.33%
#  51.28s left at 10.67%
#  51.38s left at 11.00%
#  50.70s left at 11.33%
#  54.31s left at 11.67%
#  49.02s left at 12.00%
#  50.20s left at 12.33%
#  54.68s left at 12.67%
#  56.60s left at 13.00%
#  49.64s left at 13.33%
#  50.42s left at 13.67%
#  50.77s left at 14.00%
#  49.59s left at 14.33%
#  55.32s left at 14.67%
#  49.27s left at 15.00%
#  51.83s left at 15.33%
#  47.85s left at 15.67%
#  48.32s left at 16.00%
#  48.94s left at 16.33%
#  47.62s left at 16.67%
#  47.87s left at 17.00%
#  49.22s left at 17.33%
#  48.23s left at 17.67%
#  54.68s left at 18.00%
#  50.67s left at 18.33%
#  53.18s left at 18.67%
#  48.41s left at 19.00%
#  49.38s left at 19.33%
#  46.66s left at 19.67%
#  49.27s left at 20.00%
#  58.52s left at 20.33%
#  45.14s left at 20.67%
#  46.43s left at 21.00%
#  44.85s left at 21.33%
#  45.30s left at 21.67%
#  45.49s left at 22.00%
#  45.64s left at 22.33%
#  45.33s left at 22.67%
#  47.50s left at 23.00%
#  43.39s left at 23.33%
#  47.59s left at 23.67%
#  45.63s left at 24.00%
#  45.87s left at 24.33%
#  43.89s left at 24.67%
#  47.99s left at 25.00%
#  41.99s left at 25.33%
#  46.97s left at 25.67%
#  43.39s left at 26.00%
#  42.50s left at 26.33%
#  43.40s left at 26.67%
#  21.23s left at 63.67%
#  20.54s left at 64.00%
#  21.80s left at 64.33%
#  21.05s left at 64.67%
#  20.66s left at 65.00%
#  20.46s left at 65.33%
#  19.20s left at 65.67%
#  18.80s left at 66.00%
#  19.45s left at 66.33%
#  18.93s left at 66.67%
#  18.98s left at 67.00%
#  21.39s left at 67.33%
#  18.31s left at 67.67%
#  19.30s left at 68.00%
#  19.44s left at 68.33%
#  19.52s left at 68.67%
#  24.86s left at 69.00%
#  17.95s left at 69.33%
#  18.58s left at 69.67%
#  24.38s left at 70.00%
#  20.45s left at 70.33%
#  17.14s left at 70.67%
#  16.86s left at 71.00%
#  17.83s left at 71.33%
#  16.87s left at 71.67%
#  16.49s left at 72.00%
#  17.13s left at 72.33%
#  15.70s left at 72.67%
#  14.87s left at 73.00%
#  15.12s left at 73.33%
#  14.96s left at 73.67%
#  14.17s left at 74.00%
#  14.49s left at 74.33%
#  15.02s left at 74.67%
#  14.35s left at 75.00%
#  14.74s left at 75.33%
#  13.69s left at 75.67%
#  14.15s left at 76.00%
#  13.26s left at 76.33%
#  13.13s left at 76.67%
#  13.02s left at 77.00%
#  13.73s left at 77.33%
#  12.71s left at 77.67%
#  13.38s left at 78.00%
#  12.32s left at 78.33%
#  12.50s left at 78.67%
#  11.73s left at 79.00%
#  12.54s left at 79.33%
#  11.58s left at 79.67%
#  11.20s left at 80.00%
#  11.56s left at 80.33%
#  10.77s left at 80.67%
#  11.02s left at 81.00%
#  10.59s left at 81.33%
#  10.21s left at 81.67%
#  10.07s left at 82.00%
#  10.60s left at 82.33%
#  10.12s left at 82.67%
#   9.84s left at 83.00%
#  10.82s left at 83.33%
#   9.50s left at 83.67%
#   9.53s left at 84.00%
#   9.16s left at 84.33%
#   8.98s left at 84.67%
#   8.43s left at 85.00%
#   8.51s left at 85.33%
#   8.08s left at 85.67%
#   8.24s left at 86.00%
#   9.16s left at 86.33%
#   7.53s left at 86.67%
#   7.56s left at 87.00%
#   7.10s left at 87.33%
#   6.87s left at 87.67%
#   6.70s left at 88.00%
#   6.95s left at 88.33%
#   6.55s left at 88.67%
#   6.32s left at 89.00%
#   6.02s left at 89.33%
#   5.88s left at 89.67%
#   6.61s left at 90.00%
#   6.96s left at 90.33%
#   5.41s left at 90.67%
#   5.72s left at 91.00%
#   5.39s left at 91.33%
#   5.32s left at 91.67%
#   5.01s left at 92.00%
#   4.46s left at 92.33%
#   4.13s left at 92.67%
#   4.85s left at 93.00%
#   4.51s left at 93.33%
#   4.09s left at 93.67%
#   3.90s left at 94.00%
#   3.38s left at 94.33%
#   3.16s left at 94.67%
#   3.09s left at 95.00%
#   2.94s left at 95.33%
#   2.98s left at 95.67%
#   2.35s left at 96.00%
#   2.67s left at 96.33%
#   2.03s left at 96.67%
#   1.69s left at 97.00%
#   1.55s left at 97.33%
#   1.54s left at 97.67%
#   1.13s left at 98.00%
#   1.02s left at 98.33%
#   0.77s left at 98.67%
#   0.55s left at 99.00%
#   0.37s left at 99.33%
#   0.18s left at 99.67%
# ---- Simulation stats ----
# Prob false alarm theory 0.1000
# Prob false alarm sim    0.4208
# Prob detection theory   0.6145
# Prob detection sim      0.5162

# %%
# Narrow band energy detector simulation using all available cores ("parallel" implementation)

_ = ss.sim_narrow_parallel(
    gens=50,
    itrs=10000,
    f_sample=1e6,  # in Hz
    signal_strength=0.0,  # in dB
    noise_strength=13.0,  # in dB
    length_sec=0.001024,  # in seconds
    theo_pfa=0.1,  # probability of false alarm
    noise_un=0.0)  # standard deviation of the noise normal distribution
# Out:
# ---- Simulation parameter ----
# Generations:    50
# Iterations:     10000
# Total Iters:    500000
# Signal power:   0.00 dB
# Noise power:    13.00 dB
# Noise uncert.:  0.00 dB
# SNR:            -13.00 dB
# Signal length:  0.001024 sec
# Signal samples: 1024
# ---- Simulation stats theory ----
# Prob false alarm 0.1000
# Prob detection   0.6145
# Threshold        21253.8895
# ---- Running simulation ----
# using 8 threads on 8 cores
#    infs left at  0.00%
#  70.93s left at  2.00%
#  69.17s left at  4.00%
#  67.73s left at  6.00%
#  71.02s left at  8.00%
#  64.84s left at 10.00%
# Process ForkPoolWorker-49:
# Process ForkPoolWorker-51:
# Process ForkPoolWorker-52:
# Process ForkPoolWorker-55:
# Process ForkPoolWorker-54:
# Process ForkPoolWorker-50:
# Process ForkPoolWorker-56:
# Process ForkPoolWorker-53:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "../specsens/simulation/narrow_parallel.py", line 130, in iteration
#     sig = wm.get_soft(f_center=1e5, power=signal_strength, dB=True)
# ---------------------------------------------------------------
# KeyboardInterrupt             Traceback (most recent call last)
# <ipython-input-4-a7bf469845db> in <module>
#       9     length_sec=0.001024,  # in seconds
#      10     theo_pfa=0.1,  # probability of false alarm
# ---> 11     noise_un=0.0)  # standard deviation of the noise normal distribution
#
# ~/spectrum-sensing-salsat/code/specsens/simulation/narrow_parallel.py in sim_narrow_parallel(gens, itrs, f_sample, signal_strength, noise_strength, length_sec, num_samples, theo_pfa, threshold, noise_un)
#      83
#      84         # Run itertations in parallel and store results in result array
# ---> 85         result = p.map(f, np.arange(randi, randi+itrs))
#      86
#      87         # Cleanup parallel execution
#
# /usr/lib/python3.6/multiprocessing/pool.py in map(self, func, iterable, chunksize)
#     264         in a list that is returned.
#     265         '''
# --> 266         return self._map_async(func, iterable, mapstar, chunksize).get()
#     267
#     268     def starmap(self, func, iterable, chunksize=None):
#
# /usr/lib/python3.6/multiprocessing/pool.py in get(self, timeout)
#     636
#     637     def get(self, timeout=None):
# --> 638         self.wait(timeout)
#     639         if not self.ready():
#     640             raise TimeoutError
#
# /usr/lib/python3.6/multiprocessing/pool.py in wait(self, timeout)
#     633
#     634     def wait(self, timeout=None):
# --> 635         self._event.wait(timeout)
#     636
#     637     def get(self, timeout=None):
#
# /usr/lib/python3.6/threading.py in wait(self, timeout)
#     549             signaled = self._flag
#     550             if not signaled:
# --> 551                 signaled = self._cond.wait(timeout)
#     552             return signaled
#     553
#
# /usr/lib/python3.6/threading.py in wait(self, timeout)
#     293         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     294             if timeout is None:
# --> 295                 waiter.acquire()
#     296                 gotit = True
#     297             else:
#
# KeyboardInterrupt:
#   File "../specsens/signal/wireless_microphone.py", line 29, in get_signal
#     2. * np.pi * np.random.random_sample())  # random phase
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "../specsens/simulation/narrow_parallel.py", line 130, in iteration
#     sig = wm.get_soft(f_center=1e5, power=signal_strength, dB=True)
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "../specsens/signal/wireless_microphone.py", line 51, in get_soft
#     dB=dB)
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "../specsens/simulation/narrow_parallel.py", line 134, in iteration
#     dB=True)
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
# KeyboardInterrupt
#   File "../specsens/signal/wireless_microphone.py", line 51, in get_soft
#     dB=dB)
#   File "../specsens/signal/white_gaussian_noise.py", line 25, in get_signal
#     x = util.dB_to_factor_power(power)  # set power level using dB
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "../specsens/simulation/narrow_parallel.py", line 134, in iteration
#     dB=True)
#   File "../specsens/simulation/narrow_parallel.py", line 130, in iteration
#     sig = wm.get_soft(f_center=1e5, power=signal_strength, dB=True)
#   File "../specsens/signal/wireless_microphone.py", line 31, in get_signal
#     x /= np.std(x)  # normalize
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "../specsens/signal/white_gaussian_noise.py", line 30, in get_signal
#     x = stat.rvs(size=self.num_samples).view(
#   File "../specsens/signal/wireless_microphone.py", line 51, in get_soft
#     dB=dB)
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "../specsens/simulation/narrow_parallel.py", line 134, in iteration
#     dB=True)
#   File "../specsens/signal/white_gaussian_noise.py", line 30, in get_signal
#     x = stat.rvs(size=self.num_samples).view(
#   File "/home/fabian/.local/lib/python3.6/site-packages/scipy/stats/_multivariate.py", line 762, in rvs
#     return self._dist.rvs(self.mean, self.cov, size, random_state)
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "../specsens/simulation/narrow_parallel.py", line 134, in iteration
#     dB=True)
#   File "../specsens/signal/util.py", line 47, in dB_to_factor_power
#     assert np.all(np.isreal(x)), 'x cant be complex'
#   File "/home/fabian/.local/lib/python3.6/site-packages/scipy/stats/_multivariate.py", line 762, in rvs
#     return self._dist.rvs(self.mean, self.cov, size, random_state)
#   File "../specsens/signal/wireless_microphone.py", line 29, in get_signal
#     2. * np.pi * np.random.random_sample())  # random phase
#   File "<__array_function__ internals>", line 6, in isreal
#   File "<__array_function__ internals>", line 6, in std
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/home/fabian/.local/lib/python3.6/site-packages/numpy/lib/type_check.py", line 248, in isreal
#     @array_function_dispatch(_is_type_dispatcher)
#   File "/home/fabian/.local/lib/python3.6/site-packages/scipy/stats/_multivariate.py", line 660, in rvs
#     out = random_state.multivariate_normal(mean, cov, size)
#   File "/home/fabian/.local/lib/python3.6/site-packages/scipy/stats/_multivariate.py", line 660, in rvs
#     out = random_state.multivariate_normal(mean, cov, size)
#   File "../specsens/simulation/narrow_parallel.py", line 134, in iteration
#     dB=True)
#   File "/home/fabian/.local/lib/python3.6/site-packages/numpy/core/fromnumeric.py", line 3459, in std
#     **kwargs)
#   File "mtrand.pyx", line 4089, in numpy.random.mtrand.RandomState.multivariate_normal
#   File "../specsens/signal/white_gaussian_noise.py", line 29, in get_signal
#     cov=[[.5 * x, 0.], [0., .5 * x]])
# KeyboardInterrupt
#   File "mtrand.pyx", line 4082, in numpy.random.mtrand.RandomState.multivariate_normal
# KeyboardInterrupt
#   File "/home/fabian/.local/lib/python3.6/site-packages/scipy/stats/_multivariate.py", line 363, in __call__
#     seed=seed)
#   File "/home/fabian/.local/lib/python3.6/site-packages/scipy/linalg/decomp_svd.py", line 16, in svd
#     def svd(a, full_matrices=True, compute_uv=True, overwrite_a=False,
#   File "../specsens/signal/white_gaussian_noise.py", line 29, in get_signal
#     cov=[[.5 * x, 0.], [0., .5 * x]])
#   File "/home/fabian/.local/lib/python3.6/site-packages/scipy/stats/_multivariate.py", line 736, in __init__
#     self.cov_info = _PSD(self.cov, allow_singular=allow_singular)
#   File "<__array_function__ internals>", line 6, in allclose
# KeyboardInterrupt
#   File "/home/fabian/.local/lib/python3.6/site-packages/numpy/core/_methods.py", line 217, in _std
#     keepdims=keepdims)
#   File "/home/fabian/.local/lib/python3.6/site-packages/scipy/stats/_multivariate.py", line 363, in __call__
#     seed=seed)
#   File "/home/fabian/.local/lib/python3.6/site-packages/scipy/stats/_multivariate.py", line 164, in __init__
#     s_pinv = _pinv_1d(s, eps)
#   File "/home/fabian/.local/lib/python3.6/site-packages/scipy/stats/_multivariate.py", line 733, in __init__
#     self._dist = multivariate_normal_gen(seed)
#   File "/home/fabian/.local/lib/python3.6/site-packages/numpy/core/numeric.py", line 2159, in allclose
#     res = all(isclose(a, b, rtol=rtol, atol=atol, equal_nan=equal_nan))
#   File "/home/fabian/.local/lib/python3.6/site-packages/numpy/core/_methods.py", line 177, in _var
#     if dtype is None and issubclass(arr.dtype.type, (nt.integer, nt.bool_)):
#   File "/home/fabian/.local/lib/python3.6/site-packages/scipy/stats/_multivariate.py", line 108, in _pinv_1d
#     return np.array([0 if abs(x) <= eps else 1/x for x in v], dtype=float)
# KeyboardInterrupt
#   File "<__array_function__ internals>", line 6, in isclose
#   File "/home/fabian/.local/lib/python3.6/site-packages/scipy/stats/_multivariate.py", line 108, in <listcomp>
#     return np.array([0 if abs(x) <= eps else 1/x for x in v], dtype=float)
#   File "/home/fabian/.local/lib/python3.6/site-packages/scipy/stats/_multivariate.py", line 352, in __init__
#     self.__doc__ = doccer.docformat(self.__doc__, mvn_docdict_params)
#   File "/home/fabian/.local/lib/python3.6/site-packages/scipy/_lib/doccer.py", line 55, in docformat
#     icount = indentcount_lines(lines[1:])
#   File "/home/fabian/.local/lib/python3.6/site-packages/numpy/core/numeric.py", line 2260, in isclose
#     return within_tol(x, y, atol, rtol)
# KeyboardInterrupt
#   File "/home/fabian/.local/lib/python3.6/site-packages/scipy/_lib/doccer.py", line 196, in indentcount_lines
#     stripped = line.lstrip()
#   File "/home/fabian/.local/lib/python3.6/site-packages/numpy/core/numeric.py", line 2246, in within_tol
#     return less_equal(abs(x-y), atol + rtol * abs(y))
# KeyboardInterrupt
# KeyboardInterrupt
