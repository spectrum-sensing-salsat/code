# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
from scipy import signal
import multiprocessing as mp
# from itertools import product
from functools import partial
import tqdm
import time

import sys
sys.path.insert(0, '..')
import specsens as ss

# %%
ss.simulation(
    gens=50,
    itrs=10000,
    f_sample=1e6,  # in Hz
    signal_strength=0.0,  # in dB
    noise_strength=13.0,  # in dB
    length_sec=0.001024,  # in seconds
    theo_pfa=0.1,
    noise_un=0.0)
# Out:
# ---- Simulation parameter ----
# Generations:    50
# Iterations:     10000
# Total Iters:    500000
# Signal power:   0.00 dB
# Noise power:    13.00 dB
# SNR:            -13.00 dB
# Signal length:  0.001024 sec
# Signal samples: 1024
# ---- Simulation stats theory ----
# Prob false alarm 0.1000
# Prob detection   0.6145
# Threshold        21253.8895
# ---- Running simulation ----
#    infs left at  0.00%
#  56.02s left at  2.00%
#  59.94s left at  4.00%
#  61.32s left at  6.00%
#  52.95s left at  8.00%
#  51.38s left at 10.00%
#  50.36s left at 12.00%
#  53.81s left at 14.00%
#  54.67s left at 16.00%
#  47.03s left at 18.00%
#  50.11s left at 20.00%
#  51.14s left at 22.00%
#  49.83s left at 24.00%
#  47.69s left at 26.00%
#  43.86s left at 28.00%
#  39.92s left at 30.00%
#  38.85s left at 32.00%
#  37.85s left at 34.00%
#  36.63s left at 36.00%
#  35.53s left at 38.00%
#  34.22s left at 40.00%
#  33.13s left at 42.00%
#  32.04s left at 44.00%
#  30.80s left at 46.00%
#  29.67s left at 48.00%
#  28.56s left at 50.00%
#  27.38s left at 52.00%
#  26.26s left at 54.00%
#  25.12s left at 56.00%
#  23.95s left at 58.00%
#  22.85s left at 60.00%
#  21.73s left at 62.00%
#  20.59s left at 64.00%
#  19.40s left at 66.00%
#  18.24s left at 68.00%
#  17.14s left at 70.00%
#  16.05s left at 72.00%
#  14.91s left at 74.00%
#  15.20s left at 76.00%
#  13.93s left at 78.00%
#  12.58s left at 80.00%
#  12.52s left at 82.00%
#  11.71s left at 84.00%
#   8.74s left at 86.00%
#   7.48s left at 88.00%
#   6.36s left at 90.00%
#   4.57s left at 92.00%
#   3.43s left at 94.00%
#   2.28s left at 96.00%
#   1.26s left at 98.00%
# ---- Simulation stats ----
# Prob false alarm theory 0.1000
# Prob false alarm sim    0.1041
# Prob detection theory   0.6145
# Prob detection sim      0.6035
# (0.10405191716112652, 0.6034527182095466)
