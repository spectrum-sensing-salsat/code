# %%
import numpy as np
import math
import matplotlib as mpl
import matplotlib.pyplot as plt
plt.style.use('seaborn-deep')
from mpl_toolkits import mplot3d as mpl3d
from scipy import signal, stats, linalg, fft

# import our 'specsens' package with the help of 'sys'
import sys
sys.path.insert(0, '..')
import specsens as ss

# %%
# narrow band energy detector simulation

_ = ss.narrowband_sim(
    gens=100,  # generations, number of environments
    itrs=300,  # iterations, number of tests in each environment
    f_sample=1e6,  # in Hz
    signal_power=0.0,  # in dB
    noise_power=10.0,  # in dB
    length_sec=0.001024,  # length of each section in seconds
    theo_pfa=0.1,  # probability of false alarm
    noise_uncert=0.0,  # standard deviation of the noise normal distribution
    seed=None,  # set seed for reproducibility
    num_procs=None)  # number of processes to run in parallel
# Out:
# ---- Simulation parameters ----
# Generations:    100
# Iterations:     300
# Total iters:    30000
# Signal power:   0.00 dB
# Sig cent. freq: -100000.0 Hz
# Noise power:    10.00 dB
# Noise uncert:   0.00 dB
# SNR:            -10.00 dB
# Signal length:  0.001024 s
# Signal samples: 1024
# ---- Simulation stats theory ----
# Prob false alarm: 0.1000
# Prob detection:   0.9608
# Threshold:        10652.1781
# ---- Running simulation ----
# Using 8 processes on 8 cores
# 100%|██████████| 100/100 [00:03<00:00, 29.14it/s]
# ---- Simulation stats ----
# Prob false alarm theory: 0.1000
# Prob false alarm sim:    0.1009
# Prob detection theory:   0.9608
# Prob detection sim:      0.9617
# ---- Distribution stats ----
# Sig present mean: 11259.9489
# Sig absent  mean: 10238.1934
# Sig present var:  121826.0932
# Sig absent  var:  103112.6444
# Sig present std:  349.0359
# Sig absent  std:  321.1116
