# %%
import numpy as np
from scipy import signal
from scipy import linalg
from scipy.io import wavfile
import scipy.io
import matplotlib as mpl
import matplotlib.pyplot as plt
import time

# %%
r, d = wavfile.read("TQ8-RKE-4F16 Hyundai Sonata 2017.wav")
dr = d[:,0]
di = d[:,1]
dc = dr + 1j*di

# len(d)/50000
# len(d)

# %%
plt.specgram(dc, NFFT=1024, Fs=r)
plt.title("PSD of 'signal' loaded from file")
plt.xlabel("Time")
plt.ylabel("Frequency")
plt.show()

# %%
# Out:
# array([[ 0.00866789+0.02041604j, -0.0380612 +0.00897434j,
#         -0.0041359 -0.05487403j, ...,  0.0204004 +0.04392795j,
#         -0.86256171+0.70257498j, -0.00698257+0.00169203j],
#        [ 0.00645403-0.0241822j , -0.02431154-0.02516225j,
#         -0.0340092 -0.15126526j, ..., -0.01869016-0.01789833j,
#         -0.48555134+0.24816104j,  0.00393014+0.00533612j],
#        [-0.00545466+0.01984471j, -0.01978494-0.00478258j,
#         -0.4450166 -0.01593939j, ..., -0.08447996+0.32837123j,
#          0.02432733+0.02200635j,  0.00324089-0.00471182j],
#        ...,
#        [-0.01051232-0.02245307j,  0.38857497-0.21943285j,
#         -0.00475767-0.00321534j, ..., -0.65329367+0.1996809j ,
#         -0.83126049+0.27139592j, -0.0033142 +0.00107217j],
#        [-0.01915109+0.00360944j,  0.11292975-0.26060174j,
#         -0.13774069-0.02574732j, ...,  0.11245276+0.16271207j,
#          0.06218952-0.26471263j,  0.00413289+0.00367151j],
#        [-0.00921693+0.00811378j,  0.01014196-0.01890985j,
#         -0.00304839+0.00540917j, ...,  0.00411852-0.01550324j,
#         -0.11526092+0.5696617j ,  0.00150618-0.00671347j]])
